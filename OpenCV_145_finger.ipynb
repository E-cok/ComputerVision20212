# %% [markdown]
# ## 1.4.5 Morphological Transformations

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
n = 3
img = cv2.imread('fingerprint.jpg', 0)
kernel0 = np.ones((n, n), np.uint8)
kernel1 = cv2.getStructuringElement(cv2.MORPH_RECT, (n, n))
kernel2 = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (n, n))
kernel3 = cv2.getStructuringElement(cv2.MORPH_CROSS, (n, n))

# %%
erosion = cv2.erode(opening, kernel2, iterations = 2) #
dilation = cv2.dilate(img, kernel2, iterations = 1)  #덧붙이기
opening = cv2.morphologyEx(dilation, cv2.MORPH_OPEN, kernel3)
closing = cv2.morphologyEx(erosion, cv2.MORPH_CLOSE, kernel0)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel0)

# %%
plt.rcParams['figure.figsize'] = (20, 20)
plt.subplot(221), plt.imshow(img, cmap = 'gray'), plt.title('Original', color = 'white')
plt.xticks([]), plt.yticks([])
plt.subplot(222), plt.imshow(dilation, cmap = 'gray'), plt.title('Transformation 1', color = 'white')
plt.xticks([]), plt.yticks([])
plt.subplot(223), plt.imshow(erosion, cmap = 'gray'), plt.title('Transformation 2', color = 'white')
plt.xticks([]), plt.yticks([])
plt.subplot(224), plt.imshow(closing, cmap = 'gray'), plt.title('Transformation 3', color = 'white')
plt.xticks([]), plt.yticks([])
plt.show()
